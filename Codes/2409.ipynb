# %%
print("Hello Worsmndgfjwhsbfjkdsngld")
# Out:
# Hello Worsmndgfjwhsbfjkdsngld

# %%
a = 2
b = 3
c = a + b
print(c)

print(a+b)
# Out:
# 5
# 5

# %%
a="Hi "
b="Bye"
print(a + b)
# Out:
# Hi Bye

# %%
a='a'
b="Hi"
print(a+b)
# Out:
# aHi

# %%
a=3
b=0.56
print(a+b)
# Out:
# 3.56
