# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
c = 3e8                 
A0 = 1.0  
B0 = 1.0
fc = 100e6              
fa = 1e6                           
fs = 500e6              
T = 1e-7               
R_load = 50.0           
Rt = 10000    
Rr = 1000
sigma = 1
Gt_dBi = 7.15
Gr_dBi = 7.15
Gt = 10**(Gt_dBi/10.0)
Gr = 10**(Gr_dBi/10.0)



t = np.arange(0, T, 1/fs)
Pt = 1

Pr = Pt * Gt * (sigma/((4 * np.pi * (Rr **2))*(4 * np.pi * (Rt **2) )))

print(Pr/Pt)

Pr_db = 10*np.log10(Pr)
print(Pr_db)
# Out:
# 3.2853396261233297e-16
# -154.8341972804419
