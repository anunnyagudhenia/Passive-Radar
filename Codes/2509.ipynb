# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 2
b = 3
c = a+b
print(c)
print("c")
# Out:
# 5
# c

# %%
a = "Hi "
b = "Bye"
print(a +              b)
# Out:
# Hi Bye

# %%
a = 4.0
b = 5.0
print(a + b)
# Out:
# 9.0

# %%
a = 3
b = 5.1
print(a+b)
# Out:
# 8.1

# %%
a='a'
b="bc"
print(a + b)
# Out:
# abc

# %%
a=2
b=3
if(a < b):
    print("a less than b")
# Out:
# a less than b

# %%
if(0):
    print("0")

# %%
if(-1):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
if(0):
    print("yes")
elif(-1):
    print("Maybe")
else:
    print("No")
# Out:
# Maybe

# %%
a=100
b=200
c=30
if(a>b):
    print("a")
    if(a>c):
        print("b")
        print(a)
    else:
        print("c")
        print(c)
elif(b>c):
    print("d")
    print(b)
else:
    print("e")
    print(c)
# Out:
# d
# 200
